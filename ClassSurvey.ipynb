# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Surv.csv')

# %% [raw]
# print(df.head())

# %%
plt.figure(figsize=(8, 6))
plt.hist(df['RAM (in GB)'], bins=10, edgecolor='black')
plt.title('histogram of RAM')
plt.xlabel('Values')
plt.ylabel('Frequency')
plt.show()
